# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # BackPropagation
#
# Estimated time needed: **30** mins

# %% [markdown]
# Backpropagation is the key algorithm used for training neural networks, allowing them to learn from data. It is based on the gradient descent optimization technique and works by iteratively adjusting the weights and biases of the network to minimize the error between the predicted and actual outputs.
#  In this lab, we will create a neural network to implement backpropagation for a XOR problem.

# %% [markdown]
# # Objective for this notebook
#
# * Train a Neural Network to Solve the XOR Problem
# * Implement Backpropagation for Neural Network Training
# * Demonstrate the Use of Activation Functions
# * Understand the Learning Process Over Multiple Epochs
# * Demonstrate Weight and Bias Adjustments via Gradient Descent
# * Evaluate the Model's Performance After Training
# * Monitor and Analyze the Training Process

# %% [markdown]
# <h2>Table of Contents</h2>
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 4>
# 1. <a href="#Import-Required-Libraries">Import Required Libraries</a><br>
# 2. <a href="#Initialize-Inputs">Initialize Inputs</a><br>
# 3. <a href="#Declare-the-network-parameters">Declare the network parameters</a><br>
# 4. <a href="#Define-the-weights">Define the weights</a><br>
# 5. <a href="#Training-the-Neural-Network">Training the Neural Network</a><br>
# 6. <a href="#Testing-the-Network">Testing the Network</a><br>
# 7. <a href="#Plot-the-error">Plot the error</a><br>
#
# </font>
# </div>

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented. 
# If you run this notebook on a different environment, e.g., your desktop, you may need to uncomment and install certain libraries.

#!pip install numpy==1.26.4
#!pip install matplotlib==3.5.2

# %% [markdown]
# ## Import Required Libraries

# %%
# Importing the required library
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Initialize Inputs
# Define the input and expected output for a XOR gate problem

# %%
# Defining inputs and expected output (XOR truth table)
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
d = np.array([0, 1, 1, 0])  # Expected output for XOR

# %% [markdown]
# # Declare the network parameters & the weights
#
# Define the network parameters such as
# 1. number of input neurons
# 2. hidden layer neurons
# 3. output neurons
# 4. learning rate
# 5. number of epochs
#
# Also, Declare the weights for the neurons. The initial weights are taken as random numbers which are then optimized by the backpropagation algorithm inside a function parameter `initialize_network_parameters()`

# %%
def initialize_network_parameters():
    # Network parameters
    inputSize = 2      # Number of input neurons (x1, x2)
    hiddenSize = 2     # Number of hidden neurons
    outputSize = 1     # Number of output neurons
    lr = 0.1           # Learning rate
    epochs = 2000000   # Number of training epochs

    # Initialize weights and biases randomly within the range [-1, 1]
    w1 = np.random.rand(hiddenSize, inputSize) * 2 - 1  # Weights from input to hidden layer
    b1 = np.random.rand(hiddenSize, 1) * 2 - 1          # Bias for hidden layer
    w2 = np.random.rand(outputSize, hiddenSize) * 2 - 1 # Weights from hidden to output layer
    b2 = np.random.rand(outputSize, 1) * 2 - 1          # Bias for output layer

    return w1, b1, w2, b2, lr, epochs

# %% [markdown]
# ## Training the Neural Network
#
# The neural network works in 5 stages:
# 1. Forward pass
#     * The input **X** is multiplied by the weights **w1** and passed through the first layer, followed by the application of the sigmoid or ReLU activation function. This gives the output for the hidden layer.
#     * The output of the hidden layer is then passed through the second set of weights **w2** to compute the final output. Again, a sigmoid activation function is used to generate the final output **a2**.
#
# 2. Error calculation
#     * The error is computed as the difference between the expected output **(d)** and the actual output **(a2)**.
# 3. Backward pass
#     * **Output Layer**: The derivative of the sigmoid activation function is applied to the error, producing the gradient for the output layer **(da2)**. This is used to calculate how much the weights in the output layer need to be adjusted.
#     * **Hidden Layer**: The error is then propagated backward to the hidden layer. The gradient at the hidden layer **(da1)** is computed by taking the dot product of the transpose of the weights **(w2.T)** and the gradient from the output layer. The derivative of the activation function (sigmoid or ReLU) is used to adjust this error.
# 4. Weights and bias updates
#     * After computing the **gradients (dz1, dz2)**, the **weights (w1, w2)** and **biases (b1, b2)** are updated using the **learning rate (lr)** and **the gradients**. The updates are done to minimize the error and improve the model’s predictions.
# 5. Training:
#     * This entire process is repeated over many iterations **(epochs)**. During each epoch, the model adjusts its weights and biases to reduce the error. Over time, the network learns to approximate the XOR function.
# Forward Pass:

# %%
# Get initialized parameters
w1, b1, w2, b2, lr, epochs = initialize_network_parameters()

# Training the network using backpropagation
error_list = []
for epoch in range(epochs):
    # Forward pass
    z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
    a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

    z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
    a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

    # Error calculation and backpropagation
    error = d - a2  # Difference between expected and actual output
    da2 = error * (a2 * (1 - a2))  # Derivative for output layer
    dz2 = da2  # Gradient for output layer

    # Propagate error to hidden layer
    da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
    dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer

    # Update weights and biases
    w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
    b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer

    w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
    b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
    if (epoch+1)%10000 == 0:
        print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
        error_list.append(np.average(abs(error)))
# Out:
# Epoch: 9999, Average error: 0.02692
# Epoch: 19999, Average error: 0.01707
# Epoch: 29999, Average error: 0.01330
# Epoch: 39999, Average error: 0.01120
# Epoch: 49999, Average error: 0.00982
# Epoch: 59999, Average error: 0.00884
# Epoch: 69999, Average error: 0.00809
# Epoch: 79999, Average error: 0.00750
# Epoch: 89999, Average error: 0.00701
# Epoch: 99999, Average error: 0.00661
# Epoch: 109999, Average error: 0.00627
# Epoch: 119999, Average error: 0.00597
# Epoch: 129999, Average error: 0.00571
# Epoch: 139999, Average error: 0.00548
# Epoch: 149999, Average error: 0.00527
# Epoch: 159999, Average error: 0.00509
# Epoch: 169999, Average error: 0.00492
# Epoch: 179999, Average error: 0.00477
# Epoch: 189999, Average error: 0.00463
# Epoch: 199999, Average error: 0.00450
# Epoch: 209999, Average error: 0.00438
# Epoch: 219999, Average error: 0.00427
# Epoch: 229999, Average error: 0.00417
# Epoch: 239999, Average error: 0.00407
# Epoch: 249999, Average error: 0.00398
# Epoch: 259999, Average error: 0.00390
# Epoch: 269999, Average error: 0.00382
# Epoch: 279999, Average error: 0.00375
# Epoch: 289999, Average error: 0.00368
# Epoch: 299999, Average error: 0.00361
# Epoch: 309999, Average error: 0.00355
# Epoch: 319999, Average error: 0.00349
# Epoch: 329999, Average error: 0.00343
# Epoch: 339999, Average error: 0.00337
# Epoch: 349999, Average error: 0.00332
# Epoch: 359999, Average error: 0.00327
# Epoch: 369999, Average error: 0.00322
# Epoch: 379999, Average error: 0.00318
# Epoch: 389999, Average error: 0.00313
# Epoch: 399999, Average error: 0.00309
# Epoch: 409999, Average error: 0.00305
# Epoch: 419999, Average error: 0.00301
# Epoch: 429999, Average error: 0.00297
# Epoch: 439999, Average error: 0.00294
# Epoch: 449999, Average error: 0.00290
# Epoch: 459999, Average error: 0.00287
# Epoch: 469999, Average error: 0.00283
# Epoch: 479999, Average error: 0.00280
# Epoch: 489999, Average error: 0.00277
# Epoch: 499999, Average error: 0.00274
# Epoch: 509999, Average error: 0.00271
# Epoch: 519999, Average error: 0.00269
# Epoch: 529999, Average error: 0.00266
# Epoch: 539999, Average error: 0.00263
# Epoch: 549999, Average error: 0.00261
# Epoch: 559999, Average error: 0.00258
# Epoch: 569999, Average error: 0.00256
# Epoch: 579999, Average error: 0.00253
# Epoch: 589999, Average error: 0.00251
# Epoch: 599999, Average error: 0.00249
# Epoch: 609999, Average error: 0.00247
# Epoch: 619999, Average error: 0.00245
# Epoch: 629999, Average error: 0.00242
# Epoch: 639999, Average error: 0.00240
# Epoch: 649999, Average error: 0.00238
# Epoch: 659999, Average error: 0.00237
# Epoch: 669999, Average error: 0.00235
# Epoch: 679999, Average error: 0.00233
# Epoch: 689999, Average error: 0.00231
# Epoch: 699999, Average error: 0.00229
# Epoch: 709999, Average error: 0.00228
# Epoch: 719999, Average error: 0.00226
# Epoch: 729999, Average error: 0.00224
# Epoch: 739999, Average error: 0.00223
# Epoch: 749999, Average error: 0.00221
# Epoch: 759999, Average error: 0.00219
# Epoch: 769999, Average error: 0.00218
# Epoch: 779999, Average error: 0.00216
# Epoch: 789999, Average error: 0.00215
# Epoch: 799999, Average error: 0.00214
# Epoch: 809999, Average error: 0.00212
# Epoch: 819999, Average error: 0.00211
# Epoch: 829999, Average error: 0.00209
# Epoch: 839999, Average error: 0.00208
# Epoch: 849999, Average error: 0.00207
# Epoch: 859999, Average error: 0.00206
# Epoch: 869999, Average error: 0.00204
# Epoch: 879999, Average error: 0.00203
# Epoch: 889999, Average error: 0.00202
# Epoch: 899999, Average error: 0.00201
# Epoch: 909999, Average error: 0.00199
# Epoch: 919999, Average error: 0.00198
# Epoch: 929999, Average error: 0.00197
# Epoch: 939999, Average error: 0.00196
# Epoch: 949999, Average error: 0.00195
# Epoch: 959999, Average error: 0.00194
# Epoch: 969999, Average error: 0.00193
# Epoch: 979999, Average error: 0.00192
# Epoch: 989999, Average error: 0.00191
# Epoch: 999999, Average error: 0.00190

# %% [markdown]
# ## Testing the Network
# After training, you can now test the neural network to verify that it has learned the XOR function and outputs the correct values close to [0, 1, 1, 0]

# %%
# Testing the trained network
z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

# Print results
print('Final output after training:', a2)
print('Ground truth', d)
print('Error after training:', error)
print('Average error: %0.05f'%np.average(abs(error)))
# Out:
# Final output after training: [[7.66413874e-05 2.03517478e-03 1.88449059e-03 9.96404121e-01]]
# Ground truth [0 0 0 1]
# Error after training: [[-7.66414242e-05 -2.03517588e-03 -1.88449157e-03  3.59588044e-03]]
# Average error: 0.00190

# %% [markdown]
# ## Plot the error
# Here, we plot the error as a function of epochs. This shows how error changed over multiple iterations of forward and backward passes and how the network learnt over time

# %%
# Plot error
plt.plot(error_list)
plt.title('Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# # Practice exercise 1

# %% [markdown]
# Implement backpropagation for **AND problem** using similar input as used for XOR problem above and plot the error

# %%
# Write your code here
# Importing the required library
import numpy as np
import matplotlib.pyplot as plt
# Defining inputs and expected output (AND truth table)
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
d = np.array([0, 0, 0, 1])  # Expected output for AND

# Get initialized parameters
w1, b1, w2, b2, lr, epochs = initialize_network_parameters()

# Training the network using backpropagation
error_list = []
for epoch in range(epochs):
    # Forward pass
    z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
    a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

    z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
    a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

    # Error calculation and backpropagation
    error = d - a2  # Difference between expected and actual output
    da2 = error * (a2 * (1 - a2))  # Derivative for output layer
    dz2 = da2  # Gradient for output layer

    # Propagate error to hidden layer
    da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
    dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer

    # Update weights and biases
    w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
    b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer

    w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
    b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
    if (epoch+1)%10000 == 0:
        print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
        error_list.append(np.average(abs(error)))

# Testing the trained network
z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

# Print results
print('Final output after training:', a2)
print('Ground truth', d)
print('Error after training:', error)
print('Average error: %0.05f'%np.average(abs(error)))

# Plot error
plt.plot(error_list)
plt.title('Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()
# Out:
# Epoch: 9999, Average error: 0.02263
# Epoch: 19999, Average error: 0.01404
# Epoch: 29999, Average error: 0.01090
# Epoch: 39999, Average error: 0.00918
# Epoch: 49999, Average error: 0.00806
# Epoch: 59999, Average error: 0.00726
# Epoch: 69999, Average error: 0.00665
# Epoch: 79999, Average error: 0.00617
# Epoch: 89999, Average error: 0.00578
# Epoch: 99999, Average error: 0.00545
# Epoch: 109999, Average error: 0.00517
# Epoch: 119999, Average error: 0.00493
# Epoch: 129999, Average error: 0.00472
# Epoch: 139999, Average error: 0.00453
# Epoch: 149999, Average error: 0.00436
# Epoch: 159999, Average error: 0.00421
# Epoch: 169999, Average error: 0.00408
# Epoch: 179999, Average error: 0.00395
# Epoch: 189999, Average error: 0.00384
# Epoch: 199999, Average error: 0.00373
# Epoch: 209999, Average error: 0.00364
# Epoch: 219999, Average error: 0.00355
# Epoch: 229999, Average error: 0.00346
# Epoch: 239999, Average error: 0.00338
# Epoch: 249999, Average error: 0.00331
# Epoch: 259999, Average error: 0.00324
# Epoch: 269999, Average error: 0.00318
# Epoch: 279999, Average error: 0.00312
# Epoch: 289999, Average error: 0.00306
# Epoch: 299999, Average error: 0.00300
# Epoch: 309999, Average error: 0.00295
# Epoch: 319999, Average error: 0.00290
# Epoch: 329999, Average error: 0.00285
# Epoch: 339999, Average error: 0.00281
# Epoch: 349999, Average error: 0.00277
# Epoch: 359999, Average error: 0.00273
# Epoch: 369999, Average error: 0.00269
# Epoch: 379999, Average error: 0.00265
# Epoch: 389999, Average error: 0.00261
# Epoch: 399999, Average error: 0.00258
# Epoch: 409999, Average error: 0.00254
# Epoch: 419999, Average error: 0.00251
# Epoch: 429999, Average error: 0.00248
# Epoch: 439999, Average error: 0.00245
# Epoch: 449999, Average error: 0.00242
# Epoch: 459999, Average error: 0.00239
# Epoch: 469999, Average error: 0.00237
# Epoch: 479999, Average error: 0.00234
# Epoch: 489999, Average error: 0.00231
# Epoch: 499999, Average error: 0.00229
# Epoch: 509999, Average error: 0.00227
# Epoch: 519999, Average error: 0.00224
# Epoch: 529999, Average error: 0.00222
# Epoch: 539999, Average error: 0.00220
# Epoch: 549999, Average error: 0.00218
# Epoch: 559999, Average error: 0.00216
# Epoch: 569999, Average error: 0.00214
# Epoch: 579999, Average error: 0.00212
# Epoch: 589999, Average error: 0.00210
# Epoch: 599999, Average error: 0.00208
# Epoch: 609999, Average error: 0.00206
# Epoch: 619999, Average error: 0.00204
# Epoch: 629999, Average error: 0.00203
# Epoch: 639999, Average error: 0.00201
# Epoch: 649999, Average error: 0.00199
# Epoch: 659999, Average error: 0.00198
# Epoch: 669999, Average error: 0.00196
# Epoch: 679999, Average error: 0.00195
# Epoch: 689999, Average error: 0.00193
# Epoch: 699999, Average error: 0.00192
# Epoch: 709999, Average error: 0.00190
# Epoch: 719999, Average error: 0.00189
# Epoch: 729999, Average error: 0.00188
# Epoch: 739999, Average error: 0.00186
# Epoch: 749999, Average error: 0.00185
# Epoch: 759999, Average error: 0.00184
# Epoch: 769999, Average error: 0.00182
# Epoch: 779999, Average error: 0.00181
# Epoch: 789999, Average error: 0.00180
# Epoch: 799999, Average error: 0.00179
# Epoch: 809999, Average error: 0.00178
# Epoch: 819999, Average error: 0.00176
# Epoch: 829999, Average error: 0.00175
# Epoch: 839999, Average error: 0.00174
# Epoch: 849999, Average error: 0.00173
# Epoch: 859999, Average error: 0.00172
# Epoch: 869999, Average error: 0.00171
# Epoch: 879999, Average error: 0.00170
# Epoch: 889999, Average error: 0.00169
# Epoch: 899999, Average error: 0.00168
# Epoch: 909999, Average error: 0.00167
# Epoch: 919999, Average error: 0.00166
# Epoch: 929999, Average error: 0.00165
# Epoch: 939999, Average error: 0.00164
# Epoch: 949999, Average error: 0.00163
# Epoch: 959999, Average error: 0.00162
# Epoch: 969999, Average error: 0.00162
# Epoch: 979999, Average error: 0.00161
# Epoch: 989999, Average error: 0.00160
# Epoch: 999999, Average error: 0.00159
# Final output after training: [[8.54997169e-05 1.82888661e-03 1.82470346e-03 9.97376725e-01]]
# Ground truth [0 0 0 1]
# Error after training: [[-8.54997568e-05 -1.82888756e-03 -1.82470442e-03  2.62327609e-03]]
# Average error: 0.00159

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
#
# X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
# d = np.array([0, 0, 0, 1])  # Expected output for AND
#
# # Get initialized parameters
# w1, b1, w2, b2, lr, epochs = initialize_network_parameters()
#
# # Training the network using backpropagation
# error_list = []
# for epoch in range(epochs):
#     # Forward pass
#     z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
#     a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
#     z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
#     a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
#     # Error calculation and backpropagation
#     error = d - a2  # Difference between expected and actual output
#     da2 = error * (a2 * (1 - a2))  # Derivative for output layer
#     dz2 = da2  # Gradient for output layer
#
#     # Propagate error to hidden layer
#     da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
#     dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer
#
#     # Update weights and biases
#     w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
#     b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer
#
#     w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
#     b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
#     if (epoch+1)%10000 == 0:
#         print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
#         error_list.append(np.average(abs(error)))
#
#
# # Testing the trained network
# z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
# a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
# z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
# a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
# # Print results
# print('\nFinal output after training:', a2)
# print('Ground truth', d)
# print('Error after training:', error)
# print('Average error: %0.05f'%np.average(abs(error)))
#
# # Plot error
# plt.plot(error_list)
# plt.title('Error')
# plt.xlabel('Epochs')
# plt.ylabel('Error')
# plt.show()
#
#
# -->

# %% [markdown]
# # Practice exercise 2

# %% [markdown]
# Now, decrease the learning rate to 0.01 and increase the number of epochs to 1000000 and check the error for XOR gate

# %%
# Write your code here
# Write your code here
# Importing the required library
import numpy as np
import matplotlib.pyplot as plt
# Defining inputs and expected output (AND truth table)
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
d = np.array([0, 0, 0, 1])  # Expected output for AND

# Get initialized parameters
w1, b1, w2, b2, lr, epochs = initialize_network_parameters()

# Training the network using backpropagation
error_list = []
for epoch in range(epochs):
    # Forward pass
    z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
    a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

    z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
    a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

    # Error calculation and backpropagation
    error = d - a2  # Difference between expected and actual output
    da2 = error * (a2 * (1 - a2))  # Derivative for output layer
    dz2 = da2  # Gradient for output layer

    # Propagate error to hidden layer
    da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
    dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer

    # Update weights and biases
    w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
    b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer

    w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
    b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
    if (epoch+1)%10000 == 0:
        print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
        error_list.append(np.average(abs(error)))

# Testing the trained network
z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

# Print results
print('Final output after training:', a2)
print('Ground truth', d)
print('Error after training:', error)
print('Average error: %0.05f'%np.average(abs(error)))

# Plot error
plt.plot(error_list)
plt.title('Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()
# Out:
# Epoch: 9999, Average error: 0.02607
# Epoch: 19999, Average error: 0.01633
# Epoch: 29999, Average error: 0.01268
# Epoch: 39999, Average error: 0.01066
# Epoch: 49999, Average error: 0.00935
# Epoch: 59999, Average error: 0.00842
# Epoch: 69999, Average error: 0.00771
# Epoch: 79999, Average error: 0.00714
# Epoch: 89999, Average error: 0.00669
# Epoch: 99999, Average error: 0.00630
# Epoch: 109999, Average error: 0.00598
# Epoch: 119999, Average error: 0.00570
# Epoch: 129999, Average error: 0.00545
# Epoch: 139999, Average error: 0.00523
# Epoch: 149999, Average error: 0.00504
# Epoch: 159999, Average error: 0.00486
# Epoch: 169999, Average error: 0.00471
# Epoch: 179999, Average error: 0.00456
# Epoch: 189999, Average error: 0.00443
# Epoch: 199999, Average error: 0.00431
# Epoch: 209999, Average error: 0.00420
# Epoch: 219999, Average error: 0.00409
# Epoch: 229999, Average error: 0.00399
# Epoch: 239999, Average error: 0.00390
# Epoch: 249999, Average error: 0.00382
# Epoch: 259999, Average error: 0.00374
# Epoch: 269999, Average error: 0.00366
# Epoch: 279999, Average error: 0.00359
# Epoch: 289999, Average error: 0.00353
# Epoch: 299999, Average error: 0.00346
# Epoch: 309999, Average error: 0.00340
# Epoch: 319999, Average error: 0.00335
# Epoch: 329999, Average error: 0.00329
# Epoch: 339999, Average error: 0.00324
# Epoch: 349999, Average error: 0.00319
# Epoch: 359999, Average error: 0.00314
# Epoch: 369999, Average error: 0.00310
# Epoch: 379999, Average error: 0.00305
# Epoch: 389999, Average error: 0.00301
# Epoch: 399999, Average error: 0.00297
# Epoch: 409999, Average error: 0.00293
# Epoch: 419999, Average error: 0.00289
# Epoch: 429999, Average error: 0.00286
# Epoch: 439999, Average error: 0.00282
# Epoch: 449999, Average error: 0.00279
# Epoch: 459999, Average error: 0.00276
# Epoch: 469999, Average error: 0.00273
# Epoch: 479999, Average error: 0.00270
# Epoch: 489999, Average error: 0.00267
# Epoch: 499999, Average error: 0.00264
# Epoch: 509999, Average error: 0.00261
# Epoch: 519999, Average error: 0.00258
# Epoch: 529999, Average error: 0.00256
# Epoch: 539999, Average error: 0.00253
# Epoch: 549999, Average error: 0.00251
# Epoch: 559999, Average error: 0.00249
# Epoch: 569999, Average error: 0.00246
# Epoch: 579999, Average error: 0.00244
# Epoch: 589999, Average error: 0.00242
# Epoch: 599999, Average error: 0.00240
# Epoch: 609999, Average error: 0.00238
# Epoch: 619999, Average error: 0.00236
# Epoch: 629999, Average error: 0.00234
# Epoch: 639999, Average error: 0.00232
# Epoch: 649999, Average error: 0.00230
# Epoch: 659999, Average error: 0.00228
# Epoch: 669999, Average error: 0.00226
# Epoch: 679999, Average error: 0.00224
# Epoch: 689999, Average error: 0.00223
# Epoch: 699999, Average error: 0.00221
# Epoch: 709999, Average error: 0.00219
# Epoch: 719999, Average error: 0.00218
# Epoch: 729999, Average error: 0.00216
# Epoch: 739999, Average error: 0.00215
# Epoch: 749999, Average error: 0.00213
# Epoch: 759999, Average error: 0.00212
# Epoch: 769999, Average error: 0.00210
# Epoch: 779999, Average error: 0.00209
# Epoch: 789999, Average error: 0.00207
# Epoch: 799999, Average error: 0.00206
# Epoch: 809999, Average error: 0.00205
# Epoch: 819999, Average error: 0.00203
# Epoch: 829999, Average error: 0.00202
# Epoch: 839999, Average error: 0.00201
# Epoch: 849999, Average error: 0.00200
# Epoch: 859999, Average error: 0.00198
# Epoch: 869999, Average error: 0.00197
# Epoch: 879999, Average error: 0.00196
# Epoch: 889999, Average error: 0.00195
# Epoch: 899999, Average error: 0.00194
# Epoch: 909999, Average error: 0.00193
# Epoch: 919999, Average error: 0.00191
# Epoch: 929999, Average error: 0.00190
# Epoch: 939999, Average error: 0.00189
# Epoch: 949999, Average error: 0.00188
# Epoch: 959999, Average error: 0.00187
# Epoch: 969999, Average error: 0.00186
# Epoch: 979999, Average error: 0.00185
# Epoch: 989999, Average error: 0.00184
# Epoch: 999999, Average error: 0.00183
# Final output after training: [[6.69347195e-05 1.85966043e-03 1.91230345e-03 9.96508130e-01]]
# Ground truth [0 0 0 1]
# Error after training: [[-6.69347499e-05 -1.85966139e-03 -1.91230447e-03  3.49187155e-03]]
# Average error: 0.00183

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
# lr = 0.01         # Learning rate
# epochs = 1000000   # Number of training epochs
#
#
# # Defining inputs and expected output (XOR truth table)
# X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
# d = np.array([0, 1, 1, 0])  # Expected output for XOR
#
# # Get initialized parameters
# w1, b1, w2, b2, lr, epochs = initialize_network_parameters()
#
# # Training the network using backpropagation
# error_list = []
# for epoch in range(epochs):
#     # Forward pass
#     z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
#     a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
#     z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
#     a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
#     # Error calculation and backpropagation
#     error = d - a2  # Difference between expected and actual output
#     da2 = error * (a2 * (1 - a2))  # Derivative for output layer
#     dz2 = da2  # Gradient for output layer
#
#     # Propagate error to hidden layer
#     da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
#     dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer
#
#     # Update weights and biases
#     w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
#     b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer
#
#     w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
#     b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
#     if (epoch+1)%10000 == 0:
#         print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
#         error_list.append(np.average(abs(error)))
#
#
# # Testing the trained network
# z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
# a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
# z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
# a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
# # Print results
# print('\nFinal output after training:', a2)
# print('Ground truth', d)
# print('Error after training:', error)
# print('Average error: %0.05f'%np.average(abs(error)))
#
#
# # Plot error
# plt.plot(error_list)
# plt.title('Error')
# plt.xlabel('Epochs')
# plt.ylabel('Error')
# plt.show()
#
#
# -->

# %% [markdown]
# ## Thank you for completing this lab!
#
# This notebook was created by [Aman Aggarwal](https://www.linkedin.com/in/aggarwal-aman/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 1.0  | Aman  |  Created the lab |
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
